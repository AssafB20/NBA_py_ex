# %%
url = 'https://www.basketball-reference.com/leagues/NBA_2023_standings.html#all_confs_standings_E'

# %%
#!pip install requests

# %%
#!pip install pandas

# %%
#!pip install beautifulsoup4

# %%
#!pip install ipywidgets

# %%
#!jupyter nbextension enable --py widgetsnbextension --sys-prefix;

# %%
#!jupyter serverextension enable voila --sys-prefix;

# %%
#!pip install lxml

# %%
import requests

data = requests.get(url)

with open("stats.html", "w+") as f:
        f.write(data.text)

# %%
from bs4 import BeautifulSoup

# %%
with open("stats.html") as f:
    page = f.read()
    
soup = BeautifulSoup(page, 'html.parser')

# %%
confs_standings_E = soup.find(id='confs_standings_E')
confs_standings_W = soup.find(id='confs_standings_W')

# %%
import pandas as pd

# %%
confs_standings = pd.read_html(str(confs_standings_E) + str(confs_standings_W))
#confs_standings_W = pd.read_html(str(confs_standings_W))

# %%
df_E = confs_standings[0]
df_W = confs_standings[1]
df_E.rename({'Eastern Conference': 'Team'}, axis=1, inplace=True)
df_W.rename({'Western Conference': 'Team'}, axis=1, inplace=True)

# %%
df_all = pd.concat([df_E, df_W], axis=0)
df_all.reset_index(drop=True, inplace=True)
df_all
# Out:
#                           Team  W  L   W/L%   GB   PS/G   PA/G    SRS
# 0          Milwaukee Bucks (1)  4  0  1.000    —  111.0  100.0  10.96
# 1            Atlanta Hawks (2)  4  1  0.800  0.5  117.6  111.2  -0.16
# 2      Cleveland Cavaliers (2)  4  1  0.800  0.5  117.0  105.2  11.63
# 3           Boston Celtics (4)  3  2  0.600  1.5  117.6  118.6   1.02
# 4       Washington Wizards (4)  3  2  0.600  1.5  112.0  110.0  -0.58
# 5          New York Knicks (4)  3  2  0.600  1.5  119.8  114.6   4.86
# 6          Toronto Raptors (7)  3  3  0.500  2.0  104.8  106.2   0.64
# 7            Chicago Bulls (7)  3  3  0.500  2.0  113.3  113.0   0.81
# 8        Charlotte Hornets (9)  2  3  0.400  2.5  118.2  116.4   4.17
# 9          Indiana Pacers (10)  2  4  0.333  3.0  117.8  121.2  -5.71
# 10             Miami Heat (10)  2  4  0.333  3.0  107.2  109.2  -1.55
# 11     Philadelphia 76ers (10)  2  4  0.333  3.0  108.5  107.5   1.93
# 12          Brooklyn Nets (13)  1  4  0.200  3.5  113.0  121.6  -0.56
# 13        Detroit Pistons (14)  1  5  0.167  4.0  109.7  122.8 -13.91
# 14          Orlando Magic (14)  1  5  0.167  4.0  105.7  109.7  -2.73
# 15  Portland Trail Blazers (1)  5  1  0.833    —  115.3  110.5   2.04
# 16       Memphis Grizzlies (2)  4  1  0.800  0.5  119.8  121.0  -0.16
# 17            Phoenix Suns (2)  4  1  0.800  0.5  117.6  105.8  15.69
# 18          Denver Nuggets (4)  4  2  0.667  1.0  114.8  116.3  -3.83
# 19               Utah Jazz (4)  4  2  0.667  1.0  115.8  113.5   0.90
# 20       San Antonio Spurs (4)  4  2  0.667  1.0  119.8  122.0  -1.95
# 21  Minnesota Timberwolves (4)  4  2  0.667  1.0  118.0  114.2   0.06
# 22    New Orleans Pelicans (8)  3  2  0.600  1.5  119.8  115.4  11.83
# 23   Golden State Warriors (8)  3  2  0.600  1.5  120.8  121.2  -2.47
# 24       Dallas Mavericks (10)  2  2  0.500  2.0  120.5  110.3  16.95
# 25  Oklahoma City Thunder (11)  2  3  0.400  2.5  111.4  111.4  -4.31
# 26   Los Angeles Clippers (11)  2  3  0.400  2.5  102.6  108.8  -8.91
# 27        Houston Rockets (13)  1  5  0.167  4.0  110.0  118.8  -6.42
# 28       Sacramento Kings (14)  0  4  0.000  4.0  113.0  120.3  -9.62
# 29     Los Angeles Lakers (14)  0  5  0.000  4.5  102.2  110.6 -11.02

# %%
#df_all.loc[df_all.Team == 'Boston Celtics  (1)']

df_all['Team'] = df_all['Team'].str.split()

# %%
for index, row in df_all.iterrows():
    df_all['Team'][index] = df_all['Team'][index][-2]
# Out:
# /var/folders/dk/mc88r6b94c1bd2g4pvrrcxww0000gn/T/ipykernel_90874/909410152.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all['Team'][index] = df_all['Team'][index][-2]

# %%
df = df_all[['Team','W','L']]

# %%
Assaf = {'W':['Warriors','Lakers','76ers','Hawks'],'L':['Pistons','Hornets'], 'score':'', 'name':'Assaf'}
Iddo = {'W':['Bucks','Celtics','Suns','Bulls'], 'L':['Jazz','Kings'], 'score':'','name':'Iddo'}
Liad = {'W': ['Cavaliers','Nets','Rapators','Pelicans'],'L':['Rockets','Thunder'], 'score':'','name':'Liad'}
Yaniv = {'W':['Nuggets','Mavericks','Timberwolves'],'L':['Spurs','Magic','Knicks'], 'score':'','name':'Yaniv'}
Berger = {'W':['Grizzlies','Clippers','Heat'],'L':['Pacers','Wizards','Blazers'], 'score':'','name':'Berger'}

# %%
names = [Assaf, Iddo, Liad, Yaniv, Berger]

# %%
try:
    import piplite
    await piplite.install(['ipywidgets'])
except ImportError:
    pass
import ipywidgets as widgets

# %%
from IPython.display import display, clear_output

# %%
button = widgets.Button(
    description='Click me',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Send',
    
        )
output = widgets.Output()

def on_button_clicked(event):
    with output:
        clear_output()
        for name in names:
            name['score'] = df.loc[df['Team'].isin(name['W']),['W']].sum(axis=0)[0] + df.loc[df['Team'].isin(name['L']),['L']].sum(axis=0)[0]
        df_scores = pd.DataFrame(names).set_index('name').sort_values('score',ascending=False)
        print(df_scores)
            
button.on_click(on_button_clicked)

vbox_result = widgets.VBox([button, output])

# %%
vbox_text = widgets.VBox([vbox_result])

# %%
page = widgets.HBox([vbox_text])
display(page)
# Out:
# HBox(children=(VBox(children=(VBox(children=(Button(description='Click me', style=ButtonStyle(), tooltip='Send…

# %%
#!pip freeze > requirements.txt
