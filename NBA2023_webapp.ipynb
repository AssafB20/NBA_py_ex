# %%
url = 'https://www.basketball-reference.com/leagues/NBA_2023_standings.html#all_confs_standings_E'

# %%
#!pip install requests

# %%
#!pip install pandas

# %%
#!pip install beautifulsoup4

# %%
#!pip install ipywidgets

# %%
#!jupyter nbextension enable --py widgetsnbextension --sys-prefix;

# %%
#!jupyter serverextension enable voila --sys-prefix;

# %%
#!pip install lxml

# %%
import requests

data = requests.get(url)

with open("stats.html", "w+") as f:
        f.write(data.text)

# %%
from bs4 import BeautifulSoup

# %%
with open("stats.html") as f:
    page = f.read()
    
soup = BeautifulSoup(page, 'html.parser')

# %%
confs_standings_E = soup.find(id='confs_standings_E')
confs_standings_W = soup.find(id='confs_standings_W')

# %%
import pandas as pd

# %%
confs_standings = pd.read_html(str(confs_standings_E) + str(confs_standings_W))
#confs_standings_W = pd.read_html(str(confs_standings_W))

# %%
df_E = confs_standings[0]
df_W = confs_standings[1]
df_E.rename({'Eastern Conference': 'Team'}, axis=1, inplace=True)
df_W.rename({'Western Conference': 'Team'}, axis=1, inplace=True)

# %%
df_all = pd.concat([df_E, df_W], axis=0)
df_all.reset_index(drop=True, inplace=True)
df_all
# Out:
#                           Team  W  L   W/L%   GB   PS/G   PA/G    SRS
# 0          Milwaukee Bucks (1)  3  0  1.000    —  108.3   97.3   9.33
# 1           Boston Celtics (2)  3  1  0.750  0.5  116.3  115.3   1.61
# 2       Washington Wizards (2)  3  1  0.750  0.5  110.8  105.8   6.21
# 3          New York Knicks (2)  3  1  0.750  0.5  122.8  113.5   9.31
# 4      Cleveland Cavaliers (2)  3  1  0.750  0.5  113.3  100.8  15.88
# 5            Atlanta Hawks (2)  3  1  0.750  0.5  113.0  111.0   0.85
# 6          Toronto Raptors (7)  3  2  0.600  1.0  107.8  105.0   7.05
# 7            Chicago Bulls (7)  3  2  0.600  1.0  111.2  109.8   5.56
# 8        Charlotte Hornets (9)  2  2  0.500  1.5  124.5  117.3  13.87
# 9              Miami Heat (10)  2  3  0.400  2.0  106.6  106.4   3.62
# 10          Brooklyn Nets (11)  1  3  0.250  2.5  110.0  119.8  -0.44
# 11     Philadelphia 76ers (12)  1  4  0.200  3.0  107.8  111.0  -1.47
# 12        Detroit Pistons (12)  1  4  0.200  3.0  109.2  120.2 -10.09
# 13         Indiana Pacers (12)  1  4  0.200  3.0  116.0  122.0  -6.52
# 14          Orlando Magic (15)  0  5  0.000  4.0  104.2  113.0  -5.29
# 15  Portland Trail Blazers (1)  4  1  0.800    —  113.4  110.4  -4.14
# 16               Utah Jazz (1)  4  1  0.800    —  118.8  112.8   5.75
# 17       Memphis Grizzlies (3)  3  1  0.750  0.5  118.5  123.8   1.76
# 18            Phoenix Suns (3)  3  1  0.750  0.5  116.0  104.5   8.98
# 19    New Orleans Pelicans (3)  3  1  0.750  0.5  122.0  113.3  19.12
# 20       San Antonio Spurs (6)  3  2  0.600  1.0  118.0  121.6  -2.80
# 21  Minnesota Timberwolves (6)  3  2  0.600  1.0  119.4  116.6  -0.94
# 22          Denver Nuggets (6)  3  2  0.600  1.0  114.4  119.4 -13.21
# 23    Los Angeles Clippers (9)  2  2  0.500  1.5  100.8  106.5 -14.64
# 24   Golden State Warriors (9)  2  2  0.500  1.5  120.3  124.0 -13.58
# 25       Dallas Mavericks (11)  1  2  0.333  2.0  117.7  105.3  22.29
# 26  Oklahoma City Thunder (12)  1  3  0.250  2.5  109.8  111.8  -9.43
# 27        Houston Rockets (13)  1  4  0.200  3.0  109.8  117.6  -3.11
# 28       Sacramento Kings (14)  0  3  0.000  3.0  114.0  118.7 -15.45
# 29     Los Angeles Lakers (14)  0  4  0.000  3.5  102.3  110.5 -19.64

# %%
#df_all.loc[df_all.Team == 'Boston Celtics  (1)']

df_all['Team'] = df_all['Team'].str.split()

# %%
for index, row in df_all.iterrows():
    df_all['Team'][index] = df_all['Team'][index][-2]
# Out:
# /var/folders/dk/mc88r6b94c1bd2g4pvrrcxww0000gn/T/ipykernel_83952/909410152.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all['Team'][index] = df_all['Team'][index][-2]

# %%
df = df_all[['Team','W','L']]

# %%
Assaf = {'W':['Warriors','Lakers','76ers','Hawks'],'L':['Pistons','Hornets'], 'score':'', 'name':'Assaf'}
Iddo = {'W':['Bucks','Celtics','Suns','Bulls'], 'L':['Jazz','Kings'], 'score':'','name':'Iddo'}
Liad = {'W': ['Cavaliers','Nets','Rapators','Pelicans'],'L':['Rockets','Thunder'], 'score':'','name':'Liad'}
Yaniv = {'W':['Nuggets','Maverics','Wolves'],'L':['Spurs','Magic','Knicks'], 'score':'','name':'Yaniv'}
Berger = {'W':['Grizzlies','Clippers','Heat'],'L':['Pacers','Wizards','Blazers'], 'score':'','name':'Berger'}

# %%
names = [Assaf, Iddo, Liad, Yaniv, Berger]

# %%
try:
    import piplite
    await piplite.install(['ipywidgets'])
except ImportError:
    pass
import ipywidgets as widgets

# %%
from IPython.display import display, clear_output

# %%
button = widgets.Button(
    description='Click me',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Send',
    
        )
output = widgets.Output()

def on_button_clicked(event):
    with output:
        clear_output()
        for name in names:
            name['score'] = df.loc[df['Team'].isin(name['W']),['W']].sum(axis=0)[0] + df.loc[df['Team'].isin(name['L']),['L']].sum(axis=0)[0]
        df_scores = pd.DataFrame(names).set_index('name').sort_values('score',ascending=False)
        print(df_scores)
            
button.on_click(on_button_clicked)

vbox_result = widgets.VBox([button, output])

# %%
vbox_text = widgets.VBox([vbox_result])

# %%
page = widgets.HBox([vbox_text])
display(page)
# Out:
# HBox(children=(VBox(children=(VBox(children=(Button(description='Click me', style=ButtonStyle(), tooltip='Send…

# %%
# !pip freeze > requirements.txt
